# %%
"""
TP CLustering - INSA
2023
@author: huguet
"""
import os
os.environ["OMP_NUM_THREADS"] = '4'

import numpy as np
import matplotlib.pyplot as plt

from scipy.io import arff

# READ a data set (arff format)

# Parser un fichier de données au format arff
# datanp est un tableau (numpy) d'exemples avec pour chacun la liste 
# des valeurs des features
#  Exemple : t =np.array([[1,2], [3,4], [5,6], [7,8]])
#
# Note  : 
# les jeux de données considérés ont seulement 2 features (dimension 2 seulement)
# chaque jeu de données contient aussi un numéro de cluster : on ignore


path = '../artificial/'
name = os.listdir(path)
#path_out = './fig/'
for i in name:
    databrut = arff.loadarff(open(path+str(i), 'r'))
    datanp = np.array([[x[0],x[1]] for x in databrut[0]])
    #print(databrut)
    #print(datanp)

    # PLOT données (en 2D) avec un scatter plot
    # Extraire chaque valeur des features pour en faire une liste
    # Exemple : 
    # - pour t1=t[:,0] --> [1, 3, 5, 7]
    # - pour t2=t[:,1] --> [2, 4, 6, 8]
    print("---------------------------------------")
    print("Récupérer les données initiales            "+ str(i))
    f0 = datanp[:,0] # tous les élements de la première colonne
    f1 = datanp[:,1] # tous les éléments de la deuxième colonne
    #print(f0)
    #print(f1)

    plt.figure(figsize=(6, 6))
    plt.scatter(f0, f1, s=10) #s pour régler l'affichage des points - s=0.01
    plt.title("Donnees initiales : "+ str(i))
    #plt.savefig(path_out+"Plot-kmeans-code1-"+str(name)+"-init.jpg",bbox_inches='tight', pad_inches=0.1)
    plt.show()
# Out:
# ---------------------------------------
# Récupérer les données initiales            disk-4000n.arff
# ---------------------------------------
# Récupérer les données initiales            disk-5000n.arff
# ---------------------------------------
# Récupérer les données initiales            zelnik4.arff
# ---------------------------------------
# Récupérer les données initiales            chainlink.arff
# ---------------------------------------
# Récupérer les données initiales            st900.arff
# ---------------------------------------
# Récupérer les données initiales            square3.arff
# ---------------------------------------
# Récupérer les données initiales            sizes5.arff
# ---------------------------------------
# Récupérer les données initiales            s-set1.arff
# ---------------------------------------
# Récupérer les données initiales            spiral.arff
# ---------------------------------------
# Récupérer les données initiales            2d-4c-no9.arff
# ---------------------------------------
# Récupérer les données initiales            convexe_identifie.arff
# ---------------------------------------
# Récupérer les données initiales            dpb.arff
# ---------------------------------------
# Récupérer les données initiales            tetra.arff
# ---------------------------------------
# Récupérer les données initiales            DS577.arff
# ---------------------------------------
# Récupérer les données initiales            dpc.arff
# ---------------------------------------
# Récupérer les données initiales            ds4c2sc8.arff
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/io/arff/_arffread.py in _loadarff(ofile)
#     810     try:
# --> 811         rel, attr = read_header(ofile)
#     812     except ValueError as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/io/arff/_arffread.py in read_header(ofile)
#     623     """Read the header of the iterable ofile."""
# --> 624     i = next(ofile)
#     625
#
# ~/opt/anaconda3/lib/python3.9/codecs.py in decode(self, input, final)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x86 in position 27: invalid start byte
#
# The above exception was the direct cause of the following exception:
#
# ParseArffError                            Traceback (most recent call last)
# /var/folders/75/4tcycylx5z38qj7fvhqx5d_w0000gn/T/ipykernel_1636/4247923980.py in <module>
#      28 #path_out = './fig/'
#      29 for i in name:
# ---> 30     databrut = arff.loadarff(open(path+str(i), 'r'))
#      31     datanp = np.array([[x[0],x[1]] for x in databrut[0]])
#      32     #print(databrut)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/io/arff/_arffread.py in loadarff(f)
#     800         ofile = open(f, 'rt')
#     801     try:
# --> 802         return _loadarff(ofile)
#     803     finally:
#     804         if ofile is not f:  # only close what we opened
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/io/arff/_arffread.py in _loadarff(ofile)
#     812     except ValueError as e:
#     813         msg = "Error while parsing header, error was: " + str(e)
# --> 814         raise ParseArffError(msg) from e
#     815
#     816     # Check whether we have a string attribute (not supported yet)
#
# ParseArffError: Error while parsing header, error was: 'utf-8' codec can't decode byte 0x86 in position 27: invalid start byte
